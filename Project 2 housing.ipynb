# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
location = "datasets/DC_Properties.csv"
housing = pd.read_csv(location)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2698: DtypeWarning: Columns (18,19,20,21,22,23,24,33,34,35,37,43,45) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
housing.head()
# Out:
#    Unnamed: 0  BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  BEDRM  \
# 0           0       4          0      Warm Cool  Y        2.0      8      4
# 1           1       3          1      Warm Cool  Y        2.0     11      5
# 2           2       3          1  Hot Water Rad  Y        2.0      9      5
# 3           3       3          1  Hot Water Rad  Y        2.0      8      5
# 4           4       2          1      Warm Cool  Y        1.0     11      3
#
#       AYB  YR_RMDL   ...     LONGITUDE  ASSESSMENT_NBHD ASSESSMENT_SUBNBHD  \
# 0  1910.0   1988.0   ...    -77.040832       Old City 2   040 D Old City 2
# 1  1898.0   2007.0   ...    -77.040764       Old City 2   040 D Old City 2
# 2  1910.0   2009.0   ...    -77.040678       Old City 2   040 D Old City 2
# 3  1900.0   2003.0   ...    -77.040629       Old City 2   040 D Old City 2
# 4  1913.0   2012.0   ...    -77.039361       Old City 2   040 D Old City 2
#
# ...

# %%
housing.columns
# Out:
# Index(['Unnamed: 0', 'BATHRM', 'HF_BATHRM', 'HEAT', 'AC', 'NUM_UNITS', 'ROOMS',
#        'BEDRM', 'AYB', 'YR_RMDL', 'EYB', 'STORIES', 'SALEDATE', 'PRICE',
#        'QUALIFIED', 'SALE_NUM', 'GBA', 'BLDG_NUM', 'STYLE', 'STRUCT', 'GRADE',
#        'CNDTN', 'EXTWALL', 'ROOF', 'INTWALL', 'KITCHENS', 'FIREPLACES',
#        'USECODE', 'LANDAREA', 'GIS_LAST_MOD_DTTM', 'SOURCE', 'CMPLX_NUM',
#        'LIVING_GBA', 'FULLADDRESS', 'CITY', 'STATE', 'ZIPCODE', 'NATIONALGRID',
#        'LATITUDE', 'LONGITUDE', 'ASSESSMENT_NBHD', 'ASSESSMENT_SUBNBHD',
#        'CENSUS_TRACT', 'CENSUS_BLOCK', 'WARD', 'SQUARE', 'X', 'Y', 'QUADRANT'],
#       dtype='object')

# %%
housing.dtypes
# Out:
# Unnamed: 0              int64
# BATHRM                  int64
# HF_BATHRM               int64
# HEAT                   object
# AC                     object
# NUM_UNITS             float64
# ROOMS                   int64
# BEDRM                   int64
# AYB                   float64
# YR_RMDL               float64
# EYB                     int64
# STORIES               float64
# SALEDATE               object
# PRICE                 float64
# QUALIFIED              object
# SALE_NUM                int64
# GBA                   float64
# BLDG_NUM                int64
# STYLE                  object
# STRUCT                 object
# GRADE                  object
# CNDTN                  object
# EXTWALL                object
# ROOF                   object
# INTWALL                object
# KITCHENS              float64
# FIREPLACES              int64
# USECODE                 int64
# LANDAREA                int64
# GIS_LAST_MOD_DTTM      object
# SOURCE                 object
# ...

# %%
housing.shape
# Out:
# (158957, 49)

# %%
housing.count()
# Out:
# Unnamed: 0            158957
# BATHRM                158957
# HF_BATHRM             158957
# HEAT                  158957
# AC                    158957
# NUM_UNITS             106696
# ROOMS                 158957
# BEDRM                 158957
# AYB                   158686
# YR_RMDL                80928
# EYB                   158957
# STORIES               106652
# SALEDATE              132187
# PRICE                  98216
# QUALIFIED             158957
# SALE_NUM              158957
# GBA                   106696
# BLDG_NUM              158957
# STYLE                 106696
# STRUCT                106696
# GRADE                 106696
# CNDTN                 106696
# EXTWALL               106696
# ROOF                  106696
# INTWALL               106696
# KITCHENS              106695
# FIREPLACES            158957
# USECODE               158957
# LANDAREA              158957
# GIS_LAST_MOD_DTTM     158957
# SOURCE                158957
# CMPLX_NUM              52261
# ...

# %%
housing.describe()
# Out:
#           Unnamed: 0         BATHRM      HF_BATHRM      NUM_UNITS  \
# count  158957.000000  158957.000000  158957.000000  106696.000000
# mean    79478.000000       1.810678       0.458237       1.198039
# std     45887.077707       0.976396       0.587571       0.596924
# min         0.000000       0.000000       0.000000       0.000000
# 25%     39739.000000       1.000000       0.000000       1.000000
# 50%     79478.000000       2.000000       0.000000       1.000000
# 75%    119217.000000       2.000000       1.000000       1.000000
# max    158956.000000      14.000000      11.000000       6.000000
#
#                ROOMS          BEDRM            AYB       YR_RMDL  \
# count  158957.000000  158957.000000  158686.000000  80928.000000
# mean        6.187736       2.732506    1941.987579   1998.243537
# std         2.618165       1.358864      33.640234     16.575786
# min         0.000000       0.000000    1754.000000     20.000000
# ...

# %%
housing_dupe = housing.duplicated()

# %%
housing.loc(housing_dupe)

# %%
housing_missing=pd.read_csv(location)
housing_missing.isnull().sum()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2698: DtypeWarning: Columns (18,19,20,21,22,23,24,33,34,35,37,43,45) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# Unnamed: 0                 0
# BATHRM                     0
# HF_BATHRM                  0
# HEAT                       0
# AC                         0
# NUM_UNITS              52261
# ROOMS                      0
# BEDRM                      0
# AYB                      271
# YR_RMDL                78029
# EYB                        0
# STORIES                52305
# SALEDATE               26770
# PRICE                  60741
# QUALIFIED                  0
# SALE_NUM                   0
# GBA                    52261
# BLDG_NUM                   0
# STYLE                  52261
# STRUCT                 52261
# GRADE                  52261
# CNDTN                  52261
# ...

# %%
housing_missing['PRICE']
# Out:
# 0         1095000.0
# 1               NaN
# 2         2100000.0
# 3         1602000.0
# 4               NaN
# 5         1950000.0
# 6               NaN
# 7         1050000.0
# 8         1430000.0
# 9               NaN
# 10              NaN
# 11              NaN
# 12              NaN
# 13              NaN
# 14        1325000.0
# 15              NaN
# 16        1240000.0
# 17              NaN
# 18              NaN
# 19         592250.0
# 20          33232.0
# 21              NaN
# 22         907400.0
# 23        1065000.0
# 24        1100000.0
# 25          20000.0
# 26              NaN
# 27         703700.0
# 28              NaN
# 29        1210000.0
#             ...
# 158927          NaN
# 158928     632400.0
# 158929     574000.0
# 158930     365000.0
# 158931     405000.0
# 158932     505000.0
# 158933     520000.0
# 158934     499900.0
# 158935     451000.0
# 158936     564900.0
# 158937          NaN
# 158938     660000.0
# 158939     380000.0
# 158940          NaN
# ...

# %%
meanP=housing['PRICE'].mean()
stdP=housing['PRICE'].std()
topP=meanP + stdP *1.96
botP=meanP -stdP *1.96

# %%
print(meanP)
print(stdP) 
print(topP)
print(botP)
# Out:
# 931351.5949336156
# 7061324.955612032
# 14771548.507933198
# -12908845.318065966

# %%
housing.loc[housing['PRICE']>topP]
# Out:
#         Unnamed: 0  BATHRM  HF_BATHRM        HEAT AC  NUM_UNITS  ROOMS  BEDRM  \
# 20164        20164       7          3     Ht Pump  Y        2.0     31     12
# 20685        20685       6          5   Warm Cool  Y        1.0     17      9
# 21880        21880       9          4   Warm Cool  Y        1.0     19      9
# 34527        34527       9          5  Forced Air  Y        2.0     25      7
# 37118        37118      11          1   Warm Cool  Y        1.0     26      7
# 97155        97155       4          0  Forced Air  Y        0.0      5      0
# 104206      104206       0          0     No Data  0        0.0      0      0
# 125662      125662       1          0     Ht Pump  Y        NaN      3      1
# 125663      125663       2          0     Ht Pump  Y        NaN      4      1
# 125664      125664       2          0     Ht Pump  Y        NaN      4      2
# 125670      125670       1          0     Ht Pump  Y        NaN      3      1
# ...

# %%
housing['PRICE'].count()
# Out:
# 98216

# %%
housingsmall = pd.DataFrame(data = housing, columns=['PRICE','GBA','ZIPCODE','SALEDATE','BEDRM','BATHRM','CITY','HF_BATHRM','WARD'])

# %%
housingsmall.count()
# Out:
# PRICE         98216
# GBA          106696
# ZIPCODE      158956
# SALEDATE     132187
# BEDRM        158957
# BATHRM       158957
# CITY         106051
# HF_BATHRM    158957
# WARD         158956
# dtype: int64

# %%
housingsmall.describe()
# Out:
#               PRICE            GBA        ZIPCODE          BEDRM  \
# count  9.821600e+04  106696.000000  158956.000000  158957.000000
# mean   9.313516e+05    1714.539889   20012.694563       2.732506
# std    7.061325e+06     880.677860      15.627084       1.358864
# min    1.000000e+00       0.000000   20001.000000       0.000000
# 25%    2.400000e+05    1190.000000   20007.000000       2.000000
# 50%    3.999990e+05    1480.000000   20011.000000       3.000000
# 75%    6.520000e+05    1966.000000   20018.000000       3.000000
# max    1.374275e+08   45384.000000   20392.000000      24.000000
#
#               BATHRM      HF_BATHRM
# count  158957.000000  158957.000000
# mean        1.810678       0.458237
# std         0.976396       0.587571
# min         0.000000       0.000000
# 25%         1.000000       0.000000
# 50%         2.000000       0.000000
# 75%         2.000000       1.000000
# max        14.000000      11.000000

# %%
housingsmall_missing=housingsmall
housingsmall_missing.isnull().sum()
# Out:
# PRICE        60741
# GBA          52261
# ZIPCODE          1
# SALEDATE     26770
# BEDRM            0
# BATHRM           0
# CITY         52906
# HF_BATHRM        0
# WARD             1
# dtype: int64

# %%
housingsmall_missing['PRICE']
# Out:
# 0         1095000.0
# 1               NaN
# 2         2100000.0
# 3         1602000.0
# 4               NaN
# 5         1950000.0
# 6               NaN
# 7         1050000.0
# 8         1430000.0
# 9               NaN
# 10              NaN
# 11              NaN
# 12              NaN
# 13              NaN
# 14        1325000.0
# 15              NaN
# 16        1240000.0
# 17              NaN
# 18              NaN
# 19         592250.0
# 20          33232.0
# 21              NaN
# 22         907400.0
# 23        1065000.0
# 24        1100000.0
# 25          20000.0
# 26              NaN
# 27         703700.0
# 28              NaN
# 29        1210000.0
#             ...
# 158927          NaN
# 158928     632400.0
# 158929     574000.0
# 158930     365000.0
# 158931     405000.0
# 158932     505000.0
# 158933     520000.0
# 158934     499900.0
# 158935     451000.0
# 158936     564900.0
# 158937          NaN
# 158938     660000.0
# 158939     380000.0
# 158940          NaN
# ...

# %%
housingsmall.groupby('ZIPCODE')

# %% [markdown]
# housingsmall['PRICE'].mean()

# %%
# average house prices by zipcode
housingsmall.groupby('ZIPCODE')["PRICE"].mean()
# Out:
# ZIPCODE
# 20001.0    5.215550e+05
# 20002.0    4.628894e+05
# 20003.0    5.992484e+05
# 20004.0    4.755701e+05
# 20005.0    2.813137e+06
# 20006.0    1.959069e+05
# 20007.0    9.794061e+05
# 20008.0    8.522766e+05
# 20009.0    6.215259e+05
# 20010.0    5.070154e+05
# 20011.0    4.259763e+05
# 20012.0    4.755227e+05
# 20015.0    7.703746e+05
# 20016.0    5.914537e+06
# 20017.0    4.087405e+05
# 20018.0    3.691101e+05
# 20019.0    2.302621e+05
# 20020.0    2.281464e+05
# 20024.0    3.808846e+05
# 20032.0    3.235769e+05
# 20036.0    4.015452e+05
# 20037.0    6.124601e+05
# 20052.0    5.378571e+05
# 20392.0    3.489169e+05
# Name: PRICE, dtype: float64

# %%
housingsmall.groupby('WARD')["PRICE"].mean()
# Out:
# WARD
# Ward 1    5.738363e+05
# Ward 2    1.098570e+06
# Ward 3    3.077716e+06
# Ward 4    4.899224e+05
# Ward 5    3.952432e+05
# Ward 6    5.268684e+05
# Ward 7    2.339222e+05
# Ward 8    2.715224e+05
# Name: PRICE, dtype: float64

# %%
housingsmall_P2 = pd.DataFrame(data = housingsmall, columns=['PRICE','GBA','ZIPCODE','SALEDATE','BEDRM','BATHRM','CITY','HF_BATHRM','AYB','WARD','LIVING_GBA'])
housingsmall_P2.head()
# Out:
#        PRICE     GBA  ZIPCODE             SALEDATE  BEDRM  BATHRM        CITY  \
# 0  1095000.0  2522.0  20009.0  2003-11-25 00:00:00      4       4  WASHINGTON
# 1        NaN  2567.0  20009.0  2000-08-17 00:00:00      5       3  WASHINGTON
# 2  2100000.0  2522.0  20009.0  2016-06-21 00:00:00      5       3  WASHINGTON
# 3  1602000.0  2484.0  20009.0  2006-07-12 00:00:00      5       3  WASHINGTON
# 4        NaN  5255.0  20009.0                  NaN      3       2  WASHINGTON
#
#    HF_BATHRM  AYB    WARD  LIVING_GBA
# 0          0  NaN  Ward 2         NaN
# 1          1  NaN  Ward 2         NaN
# 2          1  NaN  Ward 2         NaN
# 3          1  NaN  Ward 2         NaN
# 4          1  NaN  Ward 2         NaN

# %%
sns.lmplot(x='ZIPCODE', y='PRICE', data=housingsmall_P2)

# %%
sns.lmplot(x='ZIPCODE', y='PRICE', data=housingsmall_P2,
           fit_reg=False, #remove regression line
           hue='BEDRM')

# %%
sns.lmplot(x='GBA', y='PRICE', data=housingsmall_P2,
           fit_reg=False, #remove regression line
           hue='BEDRM')

# %%
plt.subplots(figsize=(13,7))

sns.violinplot(x='BEDRM', y='PRICE', data=housingsmall_P2)

# %%
housingsmall_P2.fillna(0)
# Out:
#             PRICE     GBA  ZIPCODE             SALEDATE  BEDRM  BATHRM  \
# 0       1095000.0  2522.0  20009.0  2003-11-25 00:00:00      4       4
# 1             0.0  2567.0  20009.0  2000-08-17 00:00:00      5       3
# 2       2100000.0  2522.0  20009.0  2016-06-21 00:00:00      5       3
# 3       1602000.0  2484.0  20009.0  2006-07-12 00:00:00      5       3
# 4             0.0  5255.0  20009.0                    0      3       2
# 5       1950000.0  5344.0  20009.0  2010-02-26 00:00:00      5       3
# 6             0.0  1260.0  20009.0  2011-05-02 00:00:00      2       1
# 7       1050000.0  2401.0  20009.0  2011-09-29 00:00:00      4       3
# 8       1430000.0  1488.0  20009.0  2018-05-03 00:00:00      3       3
# 9             0.0  1590.0  20009.0  2008-12-05 00:00:00      2       1
# 10            0.0  2748.0  20009.0                    0      5       3
# 11            0.0  3100.0  20009.0  2009-03-12 00:00:00      6       5
# ...

# %%
housingsmall_P2.corr()
# Out:
#                PRICE       GBA   ZIPCODE     BEDRM    BATHRM  HF_BATHRM  AYB  \
# PRICE       1.000000  0.600576  0.001467 -0.043331 -0.006536  -0.013113  NaN
# GBA         0.600576  1.000000 -0.097850  0.631736  0.682977   0.272598  NaN
# ZIPCODE     0.001467 -0.097850  1.000000 -0.071962 -0.063410  -0.020164  NaN
# BEDRM      -0.043331  0.631736 -0.071962  1.000000  0.655563   0.375568  NaN
# BATHRM     -0.006536  0.682977 -0.063410  0.655563  1.000000   0.248759  NaN
# HF_BATHRM  -0.013113  0.272598 -0.020164  0.375568  0.248759   1.000000  NaN
# AYB              NaN       NaN       NaN       NaN       NaN        NaN  NaN
# LIVING_GBA       NaN       NaN       NaN       NaN       NaN        NaN  NaN
#
#             LIVING_GBA
# PRICE              NaN
# GBA                NaN
# ZIPCODE            NaN
# BEDRM              NaN
# BATHRM             NaN
# HF_BATHRM          NaN
# AYB                NaN
# LIVING_GBA         NaN

# %%
import statsmodels.formula.api as smf

# %%
result = smf.ols('PRICE ~ GBA + BEDRM + BATHRM + HF_BATHRM + ZIPCODE', data=housingsmall_P2).fit()

# %%
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  PRICE   R-squared:                       0.409
# Model:                            OLS   Adj. R-squared:                  0.409
# Method:                 Least Squares   F-statistic:                     8012.
# Date:                Thu, 14 Mar 2019   Prob (F-statistic):               0.00
# Time:                        13:55:14   Log-Likelihood:            -8.3801e+05
# No. Observations:               57900   AIC:                         1.676e+06
# Df Residuals:                   57894   BIC:                         1.676e+06
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   1.866e+08   5.04e+06     37.054      0.000    1.77e+08    1.96e+08
# ...
